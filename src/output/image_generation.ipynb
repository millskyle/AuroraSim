# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 999999;

# %%
# %matplotlib inline
import Image
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 999999;

# %%
x = np.loadtxt('1500.dat',skiprows=1)

with open('1500.dat','r') as f:
     w,h = f.readline().split()
        
    

w,h = int(w),int(h)
plt.figure(figsize=(w/50,h/50)) 
print w,h

y = np.reshape(x, (h,w,3)) * 255



#y = np.zeros((w,h,3)) + 1

print np.shape(y)


plt.imshow(y,origin='lower',extent=(0,w,0,h))
plt.show()
# Out:
# 250 500
# (500, 250, 3)

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 999999;
